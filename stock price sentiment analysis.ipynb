# %%
import pandas as pd

# %%
df=pd.read_csv('stock_sentiment_data.csv',encoding = "ISO-8859-1")
df1=pd.read_csv('Combined_News_DJIA.csv',encoding = "ISO-8859-1")
data=df.append(df1)
data.sample(5)
# Out:
#             Date  Label                                               Top1  \
# 1644  2015-02-20      1  Everest College, a U.S.-owned chain of 14 priv...
# 555   2002-04-03      0                      Panathinaikos 1 - 0 Barcelona
# 626   2011-02-02      1  Clashes have broke out between pro and anti-go...
# 689   2002-10-11      1                    Jockey Club and BHB plan merger
# 588   2002-05-20      1                    Keegan ready to move for Anelka
#
#                                                    Top2  \
# 1644  Another atheist sentenced in Egypt. University...
# 555                        If you downloaded KaZaA (for
# 626   Mubarak says he won't stand for re-election in...
# 689                           Small sees off O'Sullivan
# 588                  England offered stairway to heaven
#
#                                                    Top3  \
# 1644  NSA/GCHQ hacked into world's largest manufactu...
# 555                                          What's new
# 626   Hundreds of pro-Mubarak supporters attack prot...
# 689                             Neath 16 - 16 Leicester
# 588                       Harrison finally gets serious
#
#                                                    Top4  \
# 1644  Family of girl strip-searched at Quebec school...
# 555                               3G: The future is not
# 626   "...it is absurd to think of this as simply cl...
# 689                            Leinster 29 - 23 Bristol
# 588                                 England 1 - 2 Italy
#
#                                                Top5  \
# 1644  Finnish President Signs Same-Sex Marriage Law
# 555                        Read my lips: NTT DoCoMo
# 626                       Internet back up in Egypt
# 689       Scarlets looking to catch cup fever again
# 588          Beverley Knight, Manchester University
#
#                                                    Top6  \
# 1644  Drug-resistant malaria has been detected at th...
# 555                                   Fu Manchu, London
# 626   Pro-Mubarak supporters are recognizably police...
# 689                           Edinburgh 27 - 17 Newport
# 588                    No16: Emmanuel Olisadebe, Poland
#
#                                                    Top7  \
# 1644  Pro-Russian rebels in eastern Ukraine have bro...
# 555                                      Giselle, Leeds
# 626   Tony Blair: Mubarak is 'immensely courageous a...
# 689   Fat cats Cardiff no longer licking the cream o...
# 588                        South Pacific cyclone danger
#
#                                                    Top8  ...  \
# 1644  President Zuma to white South Africans : "We'r...  ...
# 555                   Scenes from a Watercooler, Dublin  ...
# 626   Noam Chomsky about Egypt: This Is The Most Rem...  ...
# 689                  Woodward puts his faith in Johnson  ...
# 588                       Microsoft's Xbox moves online  ...
#
#                                                   Top16  \
# 1644  US Embassy: Turkey, US sign deal to train, arm...
# 555                     Games pioneers head for college
# 626   WikiLeaks: US and China in military standoff o...
# 689                         Pakistan 59 Australia 191-4
# 588               The BBC will never run ads, says Dyke
#
#                                                   Top17  \
# 1644  Thailand bans foreigners from paying Thai wome...
# 555                                         Green sweep
# 626      WikiLeaks' documents reveal more 9/11 suspects
# 689       How to break a world record the Radcliffe way
# 588                  Belgium poop French farewell party
#
#                                                   Top18  \
# 1644  Israel increases Gaza exports and exit permits...
# 555                      BBC news chief condemns Israel
# 626   Yemen's leader says he won't stand for re-elec...
# 689              Conkers: the game with growing support
# 588                        George Bush's speech on Cuba
#
#                                                   Top19  \
# 1644  Obama rejects as 'ugly lie' notion that West a...
# 555           Wayne's world too bland, charges watchdog
# 626   ElBaradei accuses Egyptian govt of "scare tact...
# 689     Super League semi-final: St Helens 24 - 8 Wigan
# 588                       Woods pips Monty at the death
#
#                                                   Top20  \
# 1644  Venezuelan Opposition Leaders Say Caracas Mayo...
# 555         Rashid is irreplaceable, says captain Adams
# 626   Raw Video: Dramatic New Images of Pro-Mubarak ...
# 689            Small wonder as Higgins is brushed aside
# 588      Doctors face 'MoTs' to build public confidence
#
#                                                   Top21  \
# 1644  Tel Aviv bus stabber who injured 17 indicted: ...
# 555      What the Israeli and Middle Eastern papers say
# 626   "Well, it is simple really.  The global elite ...
# 689                Wilkinson shock for Stadium of Light
# 588            Jailed Palestinian 'behind suicide bomb'
#
#                                                   Top22  \
# 1644  2 Strong Cyclones Hit Remote Parts of Northern...
# 555              RPO/Gatti, Royal Festival Hall, London
# 626   BAGHDAD  Security forces linked to Iraqi Prime...
# 689                  McNally at the double for Nicholls
# 588   Bush sets tough conditions for easing Cuba emb...
#
#                                                   Top23  \
# 1644  NATO Urges Russia To 'Withdraw All Its Forces'...
# 555                                     The paper chase
# 626   The cries of loathing for Mubarak are becoming...
# 689        'I was impressed by the big lad at the back'
# 588                    Apple has speed-bumped its iBook
#
#                                                   Top24  \
# 1644  The Islamic State caliphate is in danger of lo...
# 555                      Physios, Players, and Trainers
# 626           WikiLeaks nominated for Nobel Peace Prize
# 689                 World Cup secrets safe with Beckham
# 588   White van art in line for drawing exhibition p...
#
#                                                   Top25
# 1644  Belarusian President Lukashenka, the last dict...
# 555                              BV buys out Clickmusic
# 626   Egypt: Reporters Under Attack - Al Jazeera tar...
# 689                           Uefa gets tough on racism
# 588                        Dyke outlines digital vision
#
# [5 rows x 27 columns]

# %%
train = data[data['Date'] < '2015-01-01']
test = data[data['Date'] > '2014-12-31']
# Removing punctuations
data1=train.iloc[:,2:27]
data1.replace("[^a-zA-Z]"," ",regex=True, inplace=True)

# Renaming column names for ease of access
list1= [i for i in range(25)]
new_Index=[str(i) for i in list1]
data1.columns= new_Index
data1
# Out:
#                                                       0  \
# 0     A  hindrance to operations   extracts from the...
# 1                                             Scorecard
# 2                     Coventry caught on counter by Flo
# 3                         Pilgrim knows how to progress
# 4                                  Hitches and Horlocks
# ...                                                 ...
# 1606  Death toll among Qatars      World Cup workers...
# 1607  Saudis are eagerly awaiting the approval of a ...
# 1608  Solar Power Storage Prices Drop     In Germany...
# 1609  China businessman jailed for    years for buyi...
# 1610  AirAsia flight found at the bottom of the Java...
#
#                                                       1  \
# 0                                             Scorecard
# 1                                   The best lake scene
# 2                    United s rivals on the road to Rio
# 3                                   Thatcher facing ban
# 4                        Beckham off but United survive
# ...                                                 ...
# 1606  Fishing Supertrawlers to be banned permanently...
# 1607  Due to the fall in oil prices  Saudi Arabia is...
# 1608  North Korea Hit Again By Internet Outage  Expe...
# ...                                                 ...
# 1606  Secret flight linking Israel to the UAE reveal...
# 1607       Tibetan protests reported in China s Sichuan
# 1608  Reports reveal scale of destruction of Syrias ...
# 1609   The regime must be destroyed   Alexei Navalny...
# 1610  Greece Dissolves Parliament to Prepare for Ear...
#
#                                                      20  \
# 0        Diana s landmine crusade put Tories in a panic
# 1                  PE points the way forward to the ECB
# 2                                    Tony s pet project
# 3      Scientific evidence  unreliable   defence claims
# 4     Embattled Dobson attacks  play now  pay later ...
# ...                                                 ...
# 1606  Ukraine temporarily cuts off power supplies to...
# 1607  New Study Adds to Skepticism Among Security Ex...
# 1608  Russia will supply coal and electricity to Kie...
# 1609  Aleksei Navalny  Russian opposition leader  is...
# 1610  German Chancellor Angela Merkel in a New Year ...
#
#                                                      21  \
# 0     Yeltsin s resignation caught opposition flat f...
# 1     Campaigners keep up pressure on Nazi war crime...
# 2                               Al Nassr  Saudi Arabia
# 3        Fusco wins judicial review in extradition case
# 4                                     Doom and the Dome
# ...                                                 ...
# 1606                 Coalition plane  crashes in Syria
# 1607  US relocates       MRAPs  other military gear ...
# 1608                ISIS executes more doctors in Mosul
# 1609  Search area for Air Asia QZ     expanded  stil...
# 1610  Al Shabaab leader killed in U S  air strike in...
#
#                                                      22  \
# 0                                      Russian roulette
# 1                                        Jane Ratcliffe
# 2                                     Ideal Holmes show
# 3                         Rebels thwart Russian advance
# 4                       What is the north south divide
# ...                                                 ...
# 1606  Across the world  Silent Night  to honor WWI X...
# 1607  Russia s new military doctrine names NATO as a...
# 1608  Russia shows first sign of recession as GDP co...
# 1609       Ebola case confirmed in Glasgow   World news
# 1610  New solar power material converts    percent o...
#
#                                                      23  \
# 0                                              Sold out
# 1     Yet more things you wouldn t know without the ...
# 2                  Pinochet leaves hospital after tests
# 3                  Blair orders shake up of failing NHS
# 4                             Aitken released from jail
# ...                                                 ...
# 1606         Elderly Nigerians Rounded Up And Shot Dead
# 1607  Protesters in Mexico claim that German arms ma...
# 1608  AirAsia plane likely  at bottom of the sea   s...
# 1609  AirAsia plane carrying     people overshoots r...
# 1610  China launches website laying claim to Senkaku...
#
#                                                      24
# 0                                    Recovering a title
# 1                          Millennium bug fails to bite
# 2                                          Useful links
# 3                           Lessons of law s hard heart
# 4                                            Gone aloft
# ...                                                 ...
# 1606  Russia May Be Cut to Junk rating as S amp P Sa...
# 1607  A leading Russian elected official on Thursday...
# 1608      AirAsia Flight s Altitude Request Was Refused
# 1609  One of China s most industrialized cities has ...
# 1610        At Least    Killed in Yemen Suicide Bombing
#
# [3954 rows x 25 columns]

# %%
# Convertng headlines to lower case
for index in new_Index:
    data1[index]=data1[index].str.lower()
data1.head(1)
# Out:
#                                                    0          1  \
# 0  a  hindrance to operations   extracts from the...  scorecard
#
#                                  2                                         3  \
# 0  hughes  instant hit buoys blues  jack gets his skates on at ice cold alex
#
#                                         4  \
# 0  chaos as maracana builds up for united
#
#                                                    5  \
# 0  depleted leicester prevail as elliott spoils e...
#
#                                   6                                  7  \
# 0  hungry spurs sense rich pickings  gunners so wide of an easy target
#
#                                                8  \
# 0  derby raise a glass to strupar s debut double
#
#                                           9  ...  \
# 0  southgate strikes  leeds pay the penalty  ...
#
#                                          15  \
# 0  flintoff injury piles on woe for england
#
#                                                   16  \
# 0  hunters threaten jospin with new battle of the...
#
#                                     17                                    18  \
# 0  kohl s successor drawn into scandal  the difference between men and women
#
#                                     19  \
# 0  sara denver  nurse turned solicitor
#
#                                                20  \
# 0  diana s landmine crusade put tories in a panic
#
#                                                   21                22  \
# 0  yeltsin s resignation caught opposition flat f...  russian roulette
#
#          23                  24
# 0  sold out  recovering a title
#
# [1 rows x 25 columns]

# %%
' '.join(str(x) for x in data1.iloc[1,0:25])
# Out:
# 'scorecard the best lake scene leader  german sleaze inquiry cheerio  boyo the main recommendations has cubie killed fees  has cubie killed fees  has cubie killed fees  hopkins  furious  at foster s lack of hannibal appetite has cubie killed fees  a tale of two tails i say what i like and i like what i say elbows  eyes and nipples task force to assess risk of asteroid collision how i found myself at last on the critical list the timing of their lives dear doctor irish court halts ira man s extradition to northern ireland burundi peace initiative fades after rebels reject mandela as mediator pe points the way forward to the ecb campaigners keep up pressure on nazi war crimes suspect jane ratcliffe yet more things you wouldn t know without the movies millennium bug fails to bite'

# %%
headlines = []
for row in range(0,len(data1.index)):
    headlines.append(' '.join(str(x) for x in data1.iloc[row,0:25]))

# %%
headlines[0]
# Out:
# 'a  hindrance to operations   extracts from the leaked reports scorecard hughes  instant hit buoys blues jack gets his skates on at ice cold alex chaos as maracana builds up for united depleted leicester prevail as elliott spoils everton s party hungry spurs sense rich pickings gunners so wide of an easy target derby raise a glass to strupar s debut double southgate strikes  leeds pay the penalty hammers hand robson a youthful lesson saints party like it s      wear wolves have turned into lambs stump mike catches testy gough s taunt langer escapes to hit     flintoff injury piles on woe for england hunters threaten jospin with new battle of the somme kohl s successor drawn into scandal the difference between men and women sara denver  nurse turned solicitor diana s landmine crusade put tories in a panic yeltsin s resignation caught opposition flat footed russian roulette sold out recovering a title'

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
## implement BAG OF WORDS
countvector=CountVectorizer(ngram_range=(2,2))
traindataset=countvector.fit_transform(headlines)

# %%
# implement RandomForest Classifier
randomclassifier=RandomForestClassifier(n_estimators=200,criterion='entropy')
randomclassifier.fit(traindataset,train['Label'])
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200)

# %%
## Predict for the Test Dataset
test_transform= []
for row in range(0,len(test.index)):
    test_transform.append(' '.join(str(x) for x in test.iloc[row,2:27]))
test_dataset = countvector.transform(test_transform)
predictions = randomclassifier.predict(test_dataset)

# %%
## Import library to check accuracy
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
matrix=confusion_matrix(test['Label'],predictions)
print(matrix)
score=accuracy_score(test['Label'],predictions)
print(score)
report=classification_report(test['Label'],predictions)
print(report)
# Out:
# [[ 20 166]
#  [ 15 177]]
# 0.5211640211640212
#               precision    recall  f1-score   support
#
#            0       0.57      0.11      0.18       186
#            1       0.52      0.92      0.66       192
#
#     accuracy                           0.52       378
#    macro avg       0.54      0.51      0.42       378
# weighted avg       0.54      0.52      0.43       378
